# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshrajgaur13/ML_Lab/blob/main/ML_Lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b9c3cdc5-a966-4add-aa10-31927585823a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9c3cdc5-a966-4add-aa10-31927585823a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
file_path = 'Result-Experiment hehe.xlsx'
df = pd.read_excel(file_path)
df.head()

##i want to display all data not just head
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4    ML Lab Unnamed: 6  \
# 0     S. No.   Internal   External      Total       Grde  Internal   External
# 1          1         37         36         73          F      25.5         28
# 2          2         61         75        136         B+      30.5         38
# 3          3         50         48         98          C        27         32
# 4          4         57         48        105          C        33         38
#
#   Unnamed: 7 Unnamed: 8 Project Phase 1 Unnamed: 10 Unnamed: 11
# 0      Total       Grde        External       Total        Grde
# 1       53.5          C              36          36          B+
# 2       68.5         B+              41          41           A
# 3         59          B              37          37          B+
# 4         71         B+              37          37          B+

# %%
import pandas as pd

file_path = 'Result-Experiment hehe.xlsx'
df = pd.read_excel(file_path)

# Display the full dataframe
print(df)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4    ML Lab  \
# 0      S. No.   Internal   External      Total       Grde  Internal
# 1           1         37         36         73          F      25.5
# 2           2         61         75        136         B+      30.5
# 3           3         50         48         98          C        27
# 4           4         57         48        105          C        33
# 5           5         92         82        174         A+        41
# 6           6         48         55        103          C      23.5
# 7           7         48         21         69          F      25.5
# 8           8         47         25         72          F      30.5
# 9           9         45         51         96          C      22.5
# 10         10         52         45         97          C      25.5
# 11         11         79         62        141         B+      43.5
# 12         12         50         37         87          P      23.5
# ...

# %%
import pandas as pd
file_path = 'Result-Experiment hehe.xlsx'
df = pd.read_excel(file_path)
selected_data = df.iloc[1:, [5, 6]]
print(selected_data)
# Out:
#    ML Lab Unnamed: 6
# 1    25.5         28
# 2    30.5         38
# 3      27         32
# 4      33         38
# 5      41         40
# 6    23.5         29
# 7    25.5         29
# 8    30.5         32
# 9    22.5         32
# 10   25.5         33
# 11   43.5         38
# 12   23.5         30
# 13   28.5         33
# 14     23         33
# 15   23.5         37
# 16     29         35
# 17   25.5         30
# 18   23.5         30
# 19   23.5         32
# 20     29         31
# 21   34.5         37
# 22     30         34
# 23     29         40
# 24     32         30
# 25     33         37
# 26     23         31
# 27     24         32
# 28     32         30
# 29   23.5         34
# 30     31         38
# 31   33.5         30
# 32     23         31
# 33   23.5         31
# 34   46.5         35
# 35   47.5         38
# 36   23.5         35
# 37     47         31
# 38     24         35
# 39     48         42
# 40   23.5         30
# 41   38.5         30
# 42   47.5         41
# ...

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = df.iloc[1:, 5].values.reshape
y = df.iloc[1:, 6].values

model = LinearRegression()
model.fit(X, y)

slope = model.coef_[0]
intercept = model.intercept_

print(f"Linear Regression Equation: y = {slope:.2f} * X + {intercept:.2f}")

y_pred = model.predict(X)

plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Fitted Line')
plt.xlabel('Column E')
plt.ylabel('Column F')
plt.legend()
plt.title('Linear Regression: Column E vs Column F')
plt.show()
# Out:
# Linear Regression Equation: y = 0.43 * X + 20.38
